# %%
import pandas as pd
import numpy as np
import re
import string
import isodate
import joblib
from sqlalchemy import create_engine

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# CUDA version: 12.1
# GPU name: NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:2818@localhost:5432/youtube_trending_db"
)

# %%
df = pd.read_sql("SELECT * FROM youtube_trending_in", engine)

# %%
df["video_published_at"] = pd.to_datetime(df["video_published_at"]).dt.normalize()
df["video_trending_date"] = pd.to_datetime(df["video_trending_date"]).dt.normalize()

# %%
df = df.sort_values('video_trending_date')

# %%
df = df.drop_duplicates(
    subset='video_id',
    keep='first'
)

# %%
df["days_to_trend"] = (
    df["video_trending_date"] - df["video_published_at"]
).dt.days

# %%
df.head()
# Out:
#        video_id video_published_at video_trending_date  \
# 0   NCv-wz1nSnE         2024-10-12          2024-10-12
# 98  dBa1_GKAOAk         2024-10-10          2024-10-12
# 97  X06n_fiSY10         2024-10-10          2024-10-12
# 95  vokTtGVd4Ls         2024-10-11          2024-10-12
# 94  a4mZAMnC9A0         2024-10-09          2024-10-12
#
#                   channel_id          channel_title  \
# 0   UCmse5JbKneJqVyerfhDVYvQ           UV Creations
# 98  UCbBWncD3X_dfXwxmj4KwJnA           Sidharrth TV
# 97  UC60YvD_EAsoU2lIcQdxwR1Q   Unni Vlogs Cinephile
# 95  UCebC4x5l2-PQxg46Ucv9CsA              Crazy XYZ
# 94  UCGp21DZk5nhuESgznCO9UiA  Veyilon Entertainment
#
#                                   channel_description     channel_custom_url  \
# 0   UV Creations, founded in 2012 by V Vamsikrishn...           @uvcreations
# 98  Official page of General Entertainment Channel...    @officialsidharthtv
# 97  Hi,\nThis is my personal YouTube channel aka o...             @unnivlogs
# 95  Hello Guys, We create and upload videos relate...              @crazyxyz
# 94  Veyilon Entertainment is an online entertainme...  @veyilonentertainment
#
#    channel_published_at channel_country  \
# 0   2014-04-10 16:49:33           India
# 98  2016-03-28 13:12:34           India
# 97  2011-08-14 13:16:02           India
# 95  2017-09-10 18:22:11           India
# 94  2018-01-13 21:47:00           India
#
#                                           video_title  ... video_like_count  \
# 0   VISHWAMBHARA Official Teaser | Megastar Chiran...  ...           236311
# 98  ସିନ୍ଦୂର ଖେଳ- Sindura Khela -Mega Serial Watch ...  ...            10648
# 97  Vettaiyan Review Malayalam | Unni Vlogs Cinephile  ...             4312
# 95  All Type of Sky Shot Stash + Testing | ये धमाक...  ...           133883
# 94  Usure Needhaney | EP-1 | Manikandan Mathumathi...  ...             6666
#
#    video_comment_count channel_view_count channel_subscriber_count  \
# 0                13573          744568146                  1570000
# 98                  39         7104279192                  9060000
# 97                 464           88100899                   379000
# 95               10128         9291689782                 31400000
# 94                 160          179446735                   886000
#
#    channel_have_hidden_subscribers channel_video_count  \
# 0                            False                1023
# 98                           False               22584
# 97                           False                1544
# 95                           False                1390
# 94                           False                 787
#
#    channel_localized_title                      channel_localized_description  \
# 0             UV Creations  UV Creations, founded in 2012 by V Vamsikrishn...
# 98            Sidharrth TV  Official page of General Entertainment Channel...
# 97    Unni Vlogs Cinephile  Hi,\nThis is my personal YouTube channel aka o...
# 95               Crazy XYZ  Hello Guys, We create and upload videos relate...
# 94   Veyilon Entertainment  Veyilon Entertainment is an online entertainme...
#
#     video_trending_country  days_to_trend
# 0                    India              0
# 98                   India              2
# 97                   India              2
# 95                   India              1
# 94                   India              3
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (32329, 29)

# %%
like_th = df["video_like_count"].median()
comment_th = df["video_comment_count"].median()

df["will_trend"] = (
    (df["video_view_count"] >= 100_000) &
    (df["video_like_count"] >= like_th) &
    (df["video_comment_count"] >= comment_th)
).astype(int)

# %%
df["will_trend"].value_counts()
df["will_trend"].value_counts(normalize=True)
# Out:
# will_trend
# 0    0.620372
# 1    0.379628
# Name: proportion, dtype: float64

# %%
df = df.drop(
    columns=[
        "video_id",
        "video_trending_date",
        "video_view_count",
        "video_like_count",
        "video_comment_count",
        "channel_id",
        "channel_description",
        "channel_custom_url",
        "channel_country",
        "channel_published_at",
        "channel_have_hidden_subscribers",
        "channel_localized_title",
        "channel_localized_description",
        "video_dimension",
        "video_definition",
        "video_default_thumbnail",
        "video_licensed_content"
    ],
    errors="ignore"
)

# %%
def clean_text(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
df.columns
# Out:
# Index(['video_published_at', 'channel_title', 'video_title',
#        'video_description', 'video_category_id', 'video_tags',
#        'video_duration', 'channel_view_count', 'channel_subscriber_count',
#        'channel_video_count', 'video_trending_country', 'days_to_trend',
#        'will_trend'],
#       dtype='object')

# %%
TEXT_COLS = ["video_title", "video_description", "video_tags"]

for col in TEXT_COLS:
    df[col] = df[col].fillna("").apply(clean_text)

# %%
df["combined_text"] = (
    df["video_title"] + " " +
    df["video_description"] + " " +
    df["video_tags"]
)

# %%
URGENCY_WORDS = {
    "breaking", "update", "latest", "alert", "warning",
    "today", "now", "live", "just in",
    "ताजा", "ताज़ा", "बड़ी खबर", "आज", "अभी",
    "இப்போ", "செய்தி",
    "తాజా", "వార్త",
    "খবর", "আজ"
}

HYPE_WORDS = {
    "viral", "trending", "trend", "massive", "huge",
    "record", "historic",
    "वायरल", "ट्रेंडिंग",
    "வைரல்", "டிரெண்டிங்",
    "వైరల్", "ట్రెండింగ్",
    "ভাইরাল"
}

OFFICIAL_WORDS = {
    "official", "announced", "released", "statement",
    "report", "confirms", "results", "highlights",
    "आधिकारिक", "घोषणा", "परिणाम",
    "அதிகாரபூர்வ",
    "అధికారిక",
    "ফলাফল"
}

EMOTION_WORDS = {
    "emotional", "sad", "angry", "happy", "proud",
    "fear", "panic",
    "भावुक", "डर",
    "உணர்ச்சி",
    "భయం",
    "আবেগ"
}

# %%
def has_any(text, word_set):
    return int(any(w in text for w in word_set))

# %%
df["has_urgency"] = df["combined_text"].apply(
    lambda x: has_any(x, URGENCY_WORDS)
)

df["has_hype"] = df["combined_text"].apply(
    lambda x: has_any(x, HYPE_WORDS)
)

df["has_official_words"] = df["combined_text"].apply(
    lambda x: has_any(x, OFFICIAL_WORDS)
)

# optional (keep only if useful)
df["has_emotion"] = df["combined_text"].apply(
    lambda x: has_any(x, EMOTION_WORDS)
)

# %%
df["has_number_in_title"] = df["video_title"].str.contains(r"\d", regex=True).astype(int)
df["has_question_mark"] = df["video_title"].str.contains(r"\?", regex=True).astype(int)
df["has_exclamation"] = df["video_title"].str.contains(r"!", regex=True).astype(int)

# %%
def word_set(text):
    return set(text.split()) if text else set()

df["title_description_overlap_ratio"] = df.apply(
    lambda r: (
        len(word_set(r["video_title"]) & word_set(r["video_description"])) /
        max(1, len(word_set(r["video_title"])))
    ),
    axis=1
)

# %%
#####
import numpy as np

df["views_per_video"] = (
    df["channel_view_count"] /
    df["channel_video_count"].clip(lower=1)
)

df["subs_per_video"] = (
    df["channel_subscriber_count"] /
    df["channel_video_count"].clip(lower=1)
)

df["views_per_subscriber"] = (
    df["channel_view_count"] / df["channel_subscriber_count"]
)
df["channel_authority"] = (
    np.log1p(df["channel_view_count"]) *
    np.log1p(df["channel_subscriber_count"])
)
df["engagement_efficiency"] = (
    df["channel_view_count"] /
    (df["channel_video_count"] * df["channel_subscriber_count"])
)
df["log_video_count"] = np.log1p(df["channel_video_count"])
df["log_view_count"] = np.log1p(df["channel_view_count"])
df["log_subscriber_count"] = np.log1p(df["channel_subscriber_count"])

# -----------------------------
# 5. Replace remaining NaN / inf values

# %%
vpv_clip = df["views_per_video"].quantile(0.995)
spv_clip = df["subs_per_video"].quantile(0.995)

df["views_per_video_clipped"] = df["views_per_video"].clip(upper=vpv_clip)
df["subs_per_video_clipped"]  = df["subs_per_video"].clip(upper=spv_clip)

# %%
df["views_per_video_log"] = np.log1p(df["views_per_video_clipped"])
df["subs_per_video_log"]  = np.log1p(df["subs_per_video_clipped"])

# %%
df['views_per_video_log'].describe()
# Out:
# count    32329.000000
# mean        12.624053
# std          1.901666
# min          0.000000
# 25%         11.448253
# 50%         12.741364
# 75%         13.972055
# max         17.088844
# Name: views_per_video_log, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 3))
plt.boxplot(np.log1p(df["views_per_video"]), vert=False)
plt.title("Boxplot of log(views_per_video + 1)")
plt.xlabel("log views_per_video")
plt.tight_layout()
plt.show()

# %%
df["legacy_channel"] = (
    (df["channel_video_count"] > 5000) &
    (df["channel_subscriber_count"] > 500_000)
).astype(int)

# %%
df["video_volume_bucket"] = pd.cut(
    df["channel_video_count"],
    bins=[0, 200, 1000, 5000, np.inf],
    labels=[0, 1, 2, 3],
    include_lowest=True
)

df["video_volume_bucket"] = (
    df["video_volume_bucket"]
    .astype("float")
    .fillna(0)
    .astype(int)
)

# %%
df["video_duration_sec"] = df["video_duration"].apply(
    lambda x: isodate.parse_duration(x).total_seconds()
)

df["log_video_duration_sec"] = np.log1p(df["video_duration_sec"])

df = df.drop(columns=["video_duration", "video_duration_sec"])

# %%
df.columns
# Out:
# Index(['video_published_at', 'channel_title', 'video_title',
#        'video_description', 'video_category_id', 'video_tags',
#        'channel_view_count', 'channel_subscriber_count', 'channel_video_count',
#        'video_trending_country', 'days_to_trend', 'will_trend',
#        'combined_text', 'has_urgency', 'has_hype', 'has_official_words',
#        'has_emotion', 'has_number_in_title', 'has_question_mark',
#        'has_exclamation', 'title_description_overlap_ratio', 'views_per_video',
#        'subs_per_video', 'views_per_subscriber', 'channel_authority',
#        'engagement_efficiency', 'log_video_count', 'log_view_count',
#        'log_subscriber_count', 'views_per_video_clipped',
#        'subs_per_video_clipped', 'views_per_video_log', 'subs_per_video_log',
#        'legacy_channel', 'video_volume_bucket', 'log_video_duration_sec'],
#       dtype='object')

# %%
NUM_COLS = [
    "log_video_duration_sec",
    "log_subscriber_count",
    "log_view_count",
    "log_video_count",
    "channel_authority",
    "views_per_video_log",
    "subs_per_video_log",
    "video_volume_bucket",
    "legacy_channel"
]

# %%
import numpy as np

df_num = df[NUM_COLS].copy()

df_num = (
    df_num
    .replace([np.inf, -np.inf], np.nan)
    .dropna()
)

# %%
import matplotlib.pyplot as plt

for col in df_num.columns:
    plt.figure(figsize=(6, 4))
    plt.hist(df_num[col], bins=50)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# %%
for col in df_num.columns:
    plt.figure(figsize=(6, 2.5))
    plt.boxplot(df_num[col], vert=False)
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.tight_layout()
    plt.show()

# %%
for col in df_num.columns:
    plt.figure(figsize=(6, 4))
    plt.hist(
        df[df["will_trend"] == 1][col]
        .replace([np.inf, -np.inf], np.nan)
        .dropna(),
        bins=40,
        alpha=0.6,
        label="Trending",
        density=True
    )
    plt.hist(
        df[df["will_trend"] == 0][col]
        .replace([np.inf, -np.inf], np.nan)
        .dropna(),
        bins=40,
        alpha=0.6,
        label="Not Trending",
        density=True
    )
    plt.title(f"{col}: Trending vs Not Trending")
    plt.xlabel(col)
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
df.columns
# Out:
# Index(['video_published_at', 'channel_title', 'video_title',
#        'video_description', 'video_category_id', 'video_tags',
#        'channel_view_count', 'channel_subscriber_count', 'channel_video_count',
#        'video_trending_country', 'days_to_trend', 'will_trend',
#        'combined_text', 'has_urgency', 'has_hype', 'has_official_words',
#        'has_emotion', 'has_number_in_title', 'has_question_mark',
#        'has_exclamation', 'title_description_overlap_ratio', 'views_per_video',
#        'subs_per_video', 'views_per_subscriber', 'channel_authority',
#        'engagement_efficiency', 'log_video_count', 'log_view_count',
#        'log_subscriber_count', 'views_per_video_clipped',
#        'subs_per_video_clipped', 'views_per_video_log', 'subs_per_video_log',
#        'legacy_channel', 'video_volume_bucket', 'log_video_duration_sec'],
#       dtype='object')

# %%
df = df.drop(columns=[
    "channel_subscriber_count",
    "channel_video_count",
    "channel_view_count"
])

# %%
final_features = [
    # channel strength
    "log_video_duration_sec",
    "log_subscriber_count",
    "log_view_count",
    "channel_authority",
    "views_per_video_log",
    "subs_per_video_log",
    "legacy_channel",
    "video_volume_bucket",

    # content signals
    "has_urgency",
    "has_hype",
    "has_official_words",
    "has_emotion",
    "has_number_in_title",
    "has_question_mark",
    "has_exclamation",
    "title_description_overlap_ratio",
    'video_title',
    'video_description',
    'video_category_id',
    'video_tags',

    # video property
    "will_trend"
]

df = df[final_features]

# %%
df.head(1)
# Out:
#    log_video_duration_sec  log_subscriber_count  log_view_count  \
# 0                4.543295             14.266587       20.428315
#
#    channel_authority  views_per_video_log  subs_per_video_log  legacy_channel  \
# 0         291.442329            13.497822            7.336743               0
#
#    video_volume_bucket  has_urgency  has_hype  ...  has_emotion  \
# 0                    2            1         0  ...            0
#
#    has_number_in_title  has_question_mark  has_exclamation  \
# 0                    0                  0                0
#
#    title_description_overlap_ratio  \
# 0                              1.0
#
#                                          video_title  \
# 0  vishwambhara official teaser megastar chiranje...
#
#                                    video_description video_category_id  \
# 0  vishwambhara official teaser on uv creations v...     Entertainment
#
#                                           video_tags will_trend
# 0  vishwambhara official teasermegastar chiranjee...          1
#
# [1 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

from sentence_transformers import SentenceTransformer

# %%
X = df.drop(columns=["will_trend"])
y = df["will_trend"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
X_train.shape
# Out:
# (25863, 20)

# %%
embedder = SentenceTransformer("sentence-transformers/LaBSE", device="cuda")

def combine_text(df):
    return (df["video_title"] + " " +
            df["video_description"] + " " +
            df["video_tags"]).tolist()

X_train_text = embedder.encode(combine_text(X_train), convert_to_numpy=True)
X_test_text  = embedder.encode(combine_text(X_test), convert_to_numpy=True)

text_scaler = StandardScaler()
X_train_text = text_scaler.fit_transform(X_train_text)
X_test_text  = text_scaler.transform(X_test_text)

text_lr = LogisticRegression(max_iter=1000, class_weight="balanced")
text_lr.fit(X_train_text, y_train)

text_train_prob = text_lr.predict_proba(X_train_text)[:,1]
text_test_prob  = text_lr.predict_proba(X_test_text)[:,1]

# %%
X_train['video_category_id'].values
# Out:
# array(['Film & Animation', 'Comedy', 'Music', ..., 'Music', 'Music',
#        'Gaming'], shape=(25863,), dtype=object)

# %%
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier

# -------------------------
# 1. Categorical processing
# -------------------------
X_train["video_category_id"] = X_train["video_category_id"].astype(str)
X_test["video_category_id"]  = X_test["video_category_id"].astype(str)

CAT_COLS = ["video_category_id"]

ohe = OneHotEncoder(
    handle_unknown="ignore",
    sparse_output=False
)

X_train_cat = ohe.fit_transform(X_train[CAT_COLS])
X_test_cat  = ohe.transform(X_test[CAT_COLS])

# -------------------------
# 2. Numeric features (NO SCALER)
# -------------------------
NUM_COLS = [
    "log_video_duration_sec",
    "log_subscriber_count",
    "log_view_count",
    "channel_authority",
    "views_per_video_log",
    "subs_per_video_log",
    "legacy_channel",
    "video_volume_bucket",
]

X_train_num = X_train[NUM_COLS].values
X_test_num  = X_test[NUM_COLS].values

# -------------------------
# 3. Combine features
# -------------------------
X_train_full = np.hstack([X_train_cat, X_train_num])
X_test_full  = np.hstack([X_test_cat, X_test_num])

# -------------------------
# 4. Train RandomForest
# -------------------------
rf = RandomForestClassifier(
    n_estimators=400,
    max_depth=15,
    min_samples_leaf=5,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train_full, y_train)

# -------------------------
# 5. Probabilities
# -------------------------
rf_train_prob = rf.predict_proba(X_train_full)[:, 1]
rf_test_prob  = rf.predict_proba(X_test_full)[:, 1]

# %%
# Get OHE feature names
cat_feature_names = ohe.get_feature_names_out(CAT_COLS)

# Combine all feature names
feature_names = list(cat_feature_names) + NUM_COLS

tree = rf.estimators_[0]  # you can try different indices

from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(25, 12))
plot_tree(
    tree,
    feature_names=feature_names,
    class_names=["Not Trending", "Trending"],
    filled=True,
    rounded=True,
    max_depth=3   # VERY IMPORTANT
)
plt.show()

# %%
print(len(feature_names), rf.n_features_in_)
# Out:
# 9 23

# %%
print("rf expects:", rf.n_features_in_)
print("X_train_full has:", X_train_full.shape[1])
print("feature_names has:", len(feature_names))
# Out:
# rf expects: 23
# X_train_full has: 23
# feature_names has: 9

# %%
from sklearn.calibration import CalibratedClassifierCV

X_train_full = np.hstack([X_train_cat, X_train_num])
rf_calibrated = CalibratedClassifierCV(
    rf,
    method="isotonic",
    cv=3
)

rf_calibrated.fit(X_train_full, y_train)
# Out:
# CalibratedClassifierCV(cv=3,
#                        estimator=RandomForestClassifier(class_weight='balanced',
#                                                         max_depth=15,
#                                                         min_samples_leaf=5,
#                                                         n_estimators=400,
#                                                         n_jobs=-1,
#                                                         random_state=42),
#                        method='isotonic')

# %%
print("OHE train features:", X_train_cat.shape[1])
print("NUM features:", X_train_num.shape[1])
print("RF expects:", rf_calibrated.n_features_in_)
# Out:
# OHE train features: 15
# NUM features: 8
# RF expects: 23

# %%
cat_df = pd.DataFrame({
    "video_category_id": [str(user_input["video_category_id"])]
})

cat_feature = ohe.transform(cat_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 2
#       1 cat_df = pd.DataFrame({
# ----> 2     "video_category_id": [str(user_input["video_category_id"])]
#       3 })
#       5 cat_feature = ohe.transform(cat_df)
#
# NameError: name 'user_input' is not defined

# %%
joblib.dump(rf_calibrated, "rf_calibrated.pkl")
# Out:
# ['rf_calibrated.pkl']

# %%
PSYCH_COLS = [
    "has_urgency",
    "has_hype",
    "has_official_words",
    "has_emotion",
    "has_number_in_title",
    "has_question_mark",
    "has_exclamation",
    "title_description_overlap_ratio"
]

psych_scaler = StandardScaler()

X_train_psych = psych_scaler.fit_transform(X_train[PSYCH_COLS])
X_test_psych  = psych_scaler.transform(X_test[PSYCH_COLS])

psych_lr = LogisticRegression(
    max_iter=1000,
    class_weight="balanced"
)

psych_lr.fit(X_train_psych, y_train)

psych_train_prob = psych_lr.predict_proba(X_train_psych)[:,1]
psych_test_prob  = psych_lr.predict_proba(X_test_psych)[:,1]

# %%
X_train_stack = np.column_stack([
    text_train_prob,
    rf_train_prob,
    psych_train_prob
])

X_test_stack = np.column_stack([
    text_test_prob,
    rf_test_prob,
    psych_test_prob
])

meta_lr = LogisticRegression(max_iter=1000)
meta_lr.fit(X_train_stack, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
final_prob = meta_lr.predict_proba(X_test_stack)[:,1]

print("Final ROC-AUC:", roc_auc_score(y_test, final_prob))
# Out:
# Final ROC-AUC: 0.9405327812873051

# %%
def predict_trending(user_input):
    """
    Predict trending probability for a single YouTube video at upload time.

    Parameters
    ----------
    user_input : dict
        {
            "video_title": str,
            "video_description": str,
            "video_tags": str,
            "video_category_id": str,
            "video_duration_sec": int or float,
            "channel_subscriber_count": int,
            "channel_video_count": int,
            "channel_view_count": int
        }

    Returns
    -------
    dict with:
        final_probability
        confidence_bucket
        text_score
        numeric_score
        psychology_score
    """

    # -------------------------------
    # 1. CLEAN TEXT (same as training)
    # -------------------------------
    def clean_text(text):
        if not isinstance(text, str):
            return ""
        text = text.lower()
        text = re.sub(r"[^\w\s]", "", text)
        text = re.sub(r"\s+", " ", text).strip()
        return text

    title = clean_text(user_input.get("video_title", ""))
    desc  = clean_text(user_input.get("video_description", ""))
    tags  = clean_text(user_input.get("video_tags", ""))

    combined_text = f"{title} {desc} {tags}".strip()

    # -------------------------------
    # 2. TEXT MODEL (LaBSE + LR)
    # -------------------------------
    text_emb = embedder.encode(
        [combined_text],
        convert_to_numpy=True,
        show_progress_bar=False
    )

    text_emb = text_scaler.transform(text_emb)
    text_prob = text_lr.predict_proba(text_emb)[:, 1][0]

    # -------------------------------
    # 3. NUMERIC / CHANNEL MODEL (RF)
    # -------------------------------
    # Log-scale numeric features (same order as training)
    subs  = user_input["channel_subscriber_count"]
    views = user_input["channel_view_count"]
    vids  = user_input["channel_video_count"]
    dur   = user_input["video_duration_sec"]
    
    log_video_duration_sec = np.log1p(dur)
    log_subscriber_count   = np.log1p(subs)
    log_view_count         = np.log1p(views)
    
    views_per_video = views / max(1, vids)
    subs_per_video  = subs / max(1, vids)
    
    views_per_video = min(views_per_video, vpv_clip)
    subs_per_video  = min(subs_per_video, spv_clip)
    
    views_per_video_log = np.log1p(views_per_video)
    subs_per_video_log  = np.log1p(subs_per_video)
    
    channel_authority = np.log1p(views) * np.log1p(subs)
    
    legacy_channel = int((vids > 5000) and (subs > 500_000))
    
    video_volume_bucket = (
        0 if vids < 200 else
        1 if vids < 1000 else
        2 if vids < 5000 else
        3
    )
    
    num_features = np.array([[
        log_video_duration_sec,
        log_subscriber_count,
        log_view_count,
        channel_authority,
        views_per_video_log,
        subs_per_video_log,
        legacy_channel,
        video_volume_bucket
    ]])
    
    
    # categorical
    cat_df = pd.DataFrame(
        {"video_category_id": [str(user_input["video_category_id"])]}
    )
    cat_feature = ohe.transform(cat_df)
    
        
    # RF input
    rf_input = np.hstack([cat_feature, num_features])
    rf_prob = rf_calibrated.predict_proba(rf_input)[:, 1][0]


    # -------------------------------
    # 4. PSYCHOLOGY / STRUCTURE MODEL
    # -------------------------------
    def has_any(text, word_set):
        return int(any(w in text for w in word_set))

    URGENCY_WORDS = {
        "breaking", "update", "latest", "alert", "warning",
        "today", "now", "live", "just in",
        "ताजा", "ताज़ा", "बड़ी खबर", "आज", "अभी",
        "இப்போ", "செய்தி",
        "తాజా", "వార్త",
        "খবর", "আজ"
    }
    
    HYPE_WORDS = {
        "viral", "trending", "trend", "massive", "huge",
        "record", "historic",
        "वायरल", "ट्रेंडिंग",
        "வைரல்", "டிரெண்டிங்",
        "వైరల్", "ట్రెండింగ్",
        "ভাইরাল"
    }
    
    OFFICIAL_WORDS = {
        "official", "announced", "released", "statement",
        "report", "confirms", "results", "highlights",
        "आधिकारिक", "घोषणा", "परिणाम",
        "அதிகாரபூர்வ",
        "అధికారిక",
        "ফলাফল"
    }
    
    EMOTION_WORDS = {
        "emotional", "sad", "angry", "happy", "proud",
        "fear", "panic",
        "भावुक", "डर",
        "உணர்ச்சி",
        "భయం",
        "আবেগ"
    }

    has_urgency  = has_any(combined_text, URGENCY_WORDS)
    has_hype     = has_any(combined_text, HYPE_WORDS)
    has_official = has_any(combined_text, OFFICIAL_WORDS)
    has_emotion  = has_any(combined_text, EMOTION_WORDS)

    has_number = int(bool(re.search(r"\d", title)))
    has_qmark  = int("?" in user_input.get("video_title", ""))
    has_excl   = int("!" in user_input.get("video_title", ""))

    title_words = set(title.split())
    desc_words  = set(desc.split())
    overlap_ratio = (
        len(title_words & desc_words) / max(1, len(title_words))
    )

    psych_features = np.array([[
        has_urgency,
        has_hype,
        has_official,
        has_emotion,
        has_number,
        has_qmark,
        has_excl,
        overlap_ratio
    ]])

    psych_features = psych_scaler.transform(psych_features)
    psych_prob = psych_lr.predict_proba(psych_features)[:, 1][0]

    # -------------------------------
    # 5. STACKING META MODEL
    # -------------------------------
    stack_input = np.array([[text_prob, rf_prob, psych_prob]])
    final_prob = meta_lr.predict_proba(stack_input)[:, 1][0]

    # -------------------------------
    # 6. CONFIDENCE BUCKET
    # -------------------------------
    if final_prob < 0.20:
        bucket = "Low chance"
    elif final_prob < 0.45:
        bucket = "Medium chance"
    elif final_prob < 0.70:
        bucket = "High chance"
    else:
        bucket = "Very high chance"

    # -------------------------------
    # 7. RETURN RESULT
    # -------------------------------
    return {
        "final_probability": round(float(final_prob), 4),
        "confidence_bucket": bucket,
        "text_score": round(float(text_prob), 4),
        "numeric_score": round(float(rf_prob), 4),
        "psychology_score": round(float(psych_prob), 4)
    }

# %%
user_input = {
    "video_title": "official trailer released for upcoming blockbuster movie",
    "video_description": "production house releases official trailer of the upcoming film",
    "video_tags": "official trailer, movie release, film promotion",
    "video_category_id": "entertainment",
    "video_duration_sec": 155,
    "channel_subscriber_count": 3200000,
    "channel_video_count": 520,
    "channel_view_count": 1800000000
}


result = predict_trending(user_input)
print(result)
# Out:
# {'final_probability': 0.7595, 'confidence_bucket': 'Very high chance', 'text_score': 0.1309, 'numeric_score': 0.7754, 'psychology_score': 0.5917}
# C:\Users\AKSHAY KUMAR\Desktop\aasf project\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
user_input1 = {
    "video_title": "official music video released today",
    "video_description": "music label releases official video of the latest song",
    "video_tags": "official music video, new song release, music label",
    "video_category_id": "entertainment",
    "video_duration_sec": 230,
    "channel_subscriber_count": 72000000,
    "channel_video_count": 2100,
    "channel_view_count": 68000000000
}
result1 = predict_trending(user_input1)
print(result1)
# Out:
# {'final_probability': 0.931, 'confidence_bucket': 'Very high chance', 'text_score': 0.0622, 'numeric_score': 0.9606, 'psychology_score': 0.5527}
# C:\Users\AKSHAY KUMAR\Desktop\aasf project\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
user_input2 = {
    "video_title": "official highlights india vs australia match",
    "video_description": "official highlights released by cricket board",
    "video_tags": "official highlights, cricket match, sports update",
    "video_category_id": "sports",
    "video_duration_sec": 300,
    "channel_subscriber_count": 8400000,
    "channel_video_count": 1250,
    "channel_view_count": 2900000000
}
result2 = predict_trending(user_input2)
print(result2)
# Out:
# {'final_probability': 0.7882, 'confidence_bucket': 'Very high chance', 'text_score': 0.3561, 'numeric_score': 0.7485, 'psychology_score': 0.5984}
# C:\Users\AKSHAY KUMAR\Desktop\aasf project\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
user_input3 = {
    "video_title": "breaking news official update from government",
    "video_description": "official update shared during live press briefing",
    "video_tags": "breaking news, official update, live briefing",
    "video_category_id": "news & politics",
    "video_duration_sec": 160,
    "channel_subscriber_count": 6500000,
    "channel_video_count": 18500,
    "channel_view_count": 9200000000
}

result3 = predict_trending(user_input3)
print(result3)
# Out:
# {'final_probability': 0.5846, 'confidence_bucket': 'High chance', 'text_score': 0.0791, 'numeric_score': 0.6906, 'psychology_score': 0.5984}
# C:\Users\AKSHAY KUMAR\Desktop\aasf project\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
user_input4 = {
    "video_title": 'vishwambhara official teaser megastar chiranjeevi trisha krishnan vassishta mm keeravaani',
    "video_description": (
        'vishwambhara official teaser on uv creations vishwambhara is the latest telugu movie starring megastar chiranjeevi trisha krishnan and others directed by vassishta music by mm keeravaani and produced by uv creations vishwambharateaser thevishwambhara chiranjeevi megastarchiranjeevi trishakrishnan vassishta mmkeeravani uvcreations vishwambhara vishwambharamovie konidelachiranjeevi vishwambharatrailer latesttelugumovie latesttelugutrailers movie details movie name vishwambhara cast megastar chiranjeevi trisha krishnan technical crew writer director vassishta producers vamsi pramod vikram banner uv creations music mm keeravaani dop chota k naidu production designer as prakash costume designer sushmita konidela editor kotagiri venkateswara rao santhosh kamireddy dialogues sai madhav burra lyrics sri siva shakthi datta and chandrabose script associates srinivas gavireddy ganta sridhar nimmagadda srikanth and mayukh adithya exproducer karthik sabareesh line producer ramireddy sridhar reddy pro vamsishekar marketing first show publicity designs padma sri ads ananth kancherla click here to watch maa nanna super hero trailer httpswwwyoutubecomwatchvugv5i7yopre bhaje vaayu vegam trailer httpsyoutubeq0kqt1hkine bhaje vaayu vegam teaser httpsyoutubecjtimki7jbg bhaje vaayu vegam teaser launch by megastar chiranjeevi httpsyoutubepxogb76kgq vishwambhara title reveal concept video httpsyoutube0ho0vuay4q vishwambhara pooja ceremony httpsyoutubelibj42dx1ds follow for more updates about uv creations like httpswwwfacebookcomuvcthemoviemakers follow httpswwwinstagramcomuvcreationsofficial follow httpstwittercomuvcreations subscribe httpswwwyoutubecomcuvcreations'
    ),
    "video_tags": 'vishwambhara official teasermegastar chiranjeevitrisha krishnanvassishtamm keeravaanivishwambharateaserthevishwambharachiranjeeviuvcreationschiranjeevi new moviechiranjeevi lastest moviemegastar chiranjeevi new movie teaserlatest teasers 2024trisha new movie teaserlatest telugu movies 20242024 new moviesmegastar latest movieskonidela chiranjeevivassishta latest movieskeeravaani songschiranjeevi vishwambharatrisha latest movie',
    "video_category_id": 'entertainment',
    "video_duration_sec": 93,
    "channel_subscriber_count": 1570000,
    "channel_video_count": 13573,
    "channel_view_count": 744568146
}
result4 = predict_trending(user_input4)
print(result4)
# Out:
# {'final_probability': 0.0291, 'confidence_bucket': 'Low chance', 'text_score': 0.7004, 'numeric_score': 0.1089, 'psychology_score': 0.4828}
# C:\Users\AKSHAY KUMAR\Desktop\aasf project\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
df.head()
